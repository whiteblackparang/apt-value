# %%
import pandas as pd
from sqlalchemy import create_engine
from pathlib import Path

# %%
PROJECT_ROOT = Path.cwd().parent
risk_df = pd.read_csv(PROJECT_ROOT / "data" / "processed" / "risk_scored.csv")

engine = create_engine("mysql+pymysql://root:whiteblack@localhost/apt_value?charset=utf8mb4")
risk_df.to_sql("risk_scored", engine, if_exists="replace", index=False)
# Out:
# 13421

# %%
engine = create_engine("mysql+pymysql://root:whiteblack@localhost/apt_value?charset=utf8mb4")
result_df = pd.read_sql("DESCRIBE risk_scored;", engine)
result_df.to_csv("columns_check.csv", index=False, encoding="utf-8-sig")
